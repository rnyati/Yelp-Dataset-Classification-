# %% [markdown]
# VISUALIZATION - YELP DATASET

# %%
# IMPORTING, SCALING & SPLITTING THE DATA
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.plotly as py
import plotly.figure_factory as ff
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

import plotly 
plotly.tools.set_credentials_file(username='raghav99', api_key='rDtotlL2qKgvUqH8cBAV')
new_df = pd.read_csv('/Users/kimayadesai/Desktop/dataset/restaurants_data.csv', sep='\t')

new_df.drop(['Unnamed: 0'], axis=1, inplace=True)
X = new_df[['review_count','checkin_count','city']]
y = new_df[['stars']]

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

import time
t0 = time.clock()

# %%
# RANDOM FOREST

# Model 1
######################
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=10, max_depth=7, random_state=1)
random_forest.fit(X_train, y_train)

run_time = time.clock() - t0
y_predict = random_forest.predict(X_test)

m1a = accuracy_score(y_test, y_predict)
m1p = precision_score(y_test, y_predict, average='weighted')
m1r = recall_score(y_test, y_predict, average='weighted')

# Model 2
#################
t0 = time.clock()

random_forest = RandomForestClassifier(n_estimators=20, max_depth=8, random_state=1)
random_forest.fit(X_train, y_train)

run_time = time.clock() - t0
y_predict = random_forest.predict(X_test)

m2a = accuracy_score(y_test, y_predict)
m2p = precision_score(y_test, y_predict, average='weighted')
m2r = recall_score(y_test, y_predict, average='weighted')

# Model 3
#################

t0 = time.clock()

random_forest = RandomForestClassifier(n_estimators=100, max_depth=9, random_state=1)
random_forest.fit(X_train, y_train)

run_time = time.clock() - t0
y_predict = random_forest.predict(X_test)

m3a = accuracy_score(y_test, y_predict)
m3p = precision_score(y_test, y_predict, average='weighted')
m3r = recall_score(y_test, y_predict, average='weighted')

# Model 4
##############

t0 = time.clock()

random_forest = RandomForestClassifier(n_estimators=500, max_depth=12, random_state=1)
random_forest.fit(X_train, y_train)

run_time = time.clock() - t0
y_predict = random_forest.predict(X_test)

m4a = accuracy_score(y_test, y_predict)
m4p = precision_score(y_test, y_predict, average='weighted')
m4r = recall_score(y_test, y_predict, average='weighted')

# Model 5
############

t0 = time.clock()

random_forest = RandomForestClassifier(n_estimators=600, max_depth=15, random_state=1)
random_forest.fit(X_train, y_train)

run_time = time.clock() - t0

y_predict = random_forest.predict(X_test)
m5a = accuracy_score(y_test, y_predict)
m5p = precision_score(y_test, y_predict, average='weighted')
m5r = recall_score(y_test, y_predict, average='weighted')

# PLOTTING
######
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
    y=[m1a, m1p, m1r],
    name='n_estimators=10, max_depth=7, random_state=1',
    marker=dict(
        color='rgb(248,153,174)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
    
)
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
   y=[m2a, m2p, m2r],
       name='n_estimators=20, max_depth=8, random_state=1',
    marker=dict(
        color='rgb(191,107,176)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
    
)

trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m3a, m3p, m3r],
       name='n_estimators=100, max_depth=9, random_state=1',
    
      marker=dict(
        color='rgb(97,86,168)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
   
)

trace4 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m4a, m4p, m4r],
       name='n_estimators=500, max_depth=12, random_state=1',
    
      marker=dict(
        color='rgb(69,53,108)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
  
)

trace5 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m5a, m5p, m5r],
       name='n_estimators=600, max_depth=15, random_state=1',
    
      marker=dict(
        color='rgb(57,52,154)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
    
)
data = [trace1, trace2,trace3,trace4,trace5]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:22: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# ...

# %%
### kNN

import plotly.plotly as py
from plotly.graph_objs import *

# Model 1
######################
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train, y_train)

y_predict = neigh.predict(X_test)
m1a = (accuracy_score(y_test, y_predict))
m1p =(precision_score(y_test, y_predict, average='weighted'))
m1r = (recall_score(y_test, y_predict, average='weighted'))

# Model 2
######################

from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=50)
neigh.fit(X_train, y_train)

y_predict = neigh.predict(X_test)
m2a = (accuracy_score(y_test, y_predict))
m2p =(precision_score(y_test, y_predict, average='weighted'))
m2r = (recall_score(y_test, y_predict, average='weighted'))

# Model 3
######################

from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=100)
neigh.fit(X_train, y_train)

y_predict = neigh.predict(X_test)
m3a = (accuracy_score(y_test, y_predict))
m3p =(precision_score(y_test, y_predict, average='weighted'))
m3r = (recall_score(y_test, y_predict, average='weighted'))

# Model 4
######################

from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=300)
neigh.fit(X_train, y_train)


y_predict = neigh.predict(X_test)
m4a = (accuracy_score(y_test, y_predict))
m4p =(precision_score(y_test, y_predict, average='weighted'))
m4r = (recall_score(y_test, y_predict, average='weighted'))

# Model 5
######################

from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=500)
neigh.fit(X_train, y_train)


y_predict = neigh.predict(X_test)
m5a = (accuracy_score(y_test, y_predict))
m5p =(precision_score(y_test, y_predict, average='weighted'))
m5r = (recall_score(y_test, y_predict, average='weighted'))


### PLOTTING

import plotly.plotly as py
import plotly.graph_objs as go

trace1 = Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
    y=[m1a, m1p, m1r],
     mode='lines',
    name='n_neighbors=3',
    marker=dict(
        color='rgb(150,0,100)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
   
    
    
)

trace2 = Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
   y=[m2a, m2p, m2r],
    mode='lines',
        name='n_neighbors=50',
    marker=dict(
        color='rgb(200,0,150)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
  
    
    
)

trace3 = Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m3a, m3p, m3r],
        mode='lines',
        name='n_neighbors=100',
    marker=dict(
        color='rgb(200,150,100)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
     

    
)

trace4 = Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m4a, m4p, m4r],
     mode='lines',
        name='n_neighbors=300',
    marker=dict(
        color='rgb(200,0,200)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
    
   
    
)


trace5 = Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m5a, m5p, m5r],
      mode='lines',
        name='n_neighbors=500',
    marker=dict(
        color='rgb(200,200,0)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
    
    
  
    
)
data = [trace1, trace2,trace3,trace4,trace5]
layout = Layout(
    paper_bgcolor='rgb(255,255,255)',
    plot_bgcolor='rgb(229,229,229)',
    xaxis=XAxis(
        gridcolor='rgb(255,255,255)',
        range=[1,10],
        showgrid=True,
        showline=False,
        showticklabels=True,
        tickcolor='rgb(127,127,127)',
        ticks='outside',
        zeroline=False
    ),
    yaxis=YAxis(
        gridcolor='rgb(255,255,255)',
        showgrid=True,
        showline=False,
        showticklabels=True,
        tickcolor='rgb(127,127,127)',
        ticks='outside',
        zeroline=False
    ),
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='shaded_lines')
# Out:
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:10: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:22: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:34: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# ...

# %%
### MLP

import plotly.plotly as py
import plotly.graph_objs as go

# Model 1
###########
trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
    y=[61.3, 37.56, 61.31],
    name='hidden_layer_sizes=(100, ), activation=logistic, alpha=0.001, learning_rate=adaptive',
    marker=dict(
        color='#7ad9dc',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
    
)

# Model 2
###########
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
   y=[61.42, 44.50, 61.42],
       name='solver=lbfgs, alpha=1e-5, hidden_layer_sizes=(15, 10, 5), random_state=1',
    marker=dict(
        color='#57b4cc',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
    
)

# Model 3
###########
trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[61.5, 46.00, 61.5],
       name='solver=lbfgs, alpha=1e-5, hidden_layer_sizes=(10, 8), random_state=1',
    
      marker=dict(
        color='#d9fff4',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
   
)

# Model 4
###########
trace4 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[61.29, 43.73, 61.29],
       name='solver=lbfgs, alpha=1e-4, hidden_layer_sizes=(15, ), random_state=1, max_iter=100',
    
      marker=dict(
        color='#ff738e',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
  
)

# Model 5
###########
trace5 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[61.55, 50.19, 61.55],
       name='hidden_layer_sizes=(200, 100, ), activation=tanh, alpha=0.001, learning_rate=adaptive, solver=lbfgs',
    
      marker=dict(
        color='#ff9898',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
    
)
data = [trace1, trace2,trace3,trace4,trace5]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
#### DECISION TREE -1 
import plotly.plotly as py
import plotly.graph_objs as go

# Model 1
#########
trace1 = go.Bar(
    x=['Runtime'],
    y=[ 0.078],
    name='max_depth=5'
)

# Model 2
#########
trace2 = go.Bar(
    x=['Runtime'],
   y=[0.053],
       name='max_depth=5, presort=true'
)



data = [trace1, trace2]

layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
#### DECISION TREE - 2

# Model 1
###########

from sklearn import tree

model = tree.DecisionTreeClassifier(max_depth=5)

model.fit(X_train, y_train)
y_predict = model.predict(X_test)

m1a = (accuracy_score(y_test, y_predict))
m1p =(precision_score(y_test, y_predict, average='weighted'))
m1r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0

# Model 2
######################
from sklearn import tree

model = tree.DecisionTreeClassifier(max_depth=10)

model.fit(X_train, y_train)
y_predict = model.predict(X_test)

m2a = (accuracy_score(y_test, y_predict))
m2p =(precision_score(y_test, y_predict, average='weighted'))
m2r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0


# Model 3
######################
from sklearn import tree

model = tree.DecisionTreeClassifier(max_depth=5000)

model.fit(X_train, y_train)
y_predict = model.predict(X_test)

m3a = (accuracy_score(y_test, y_predict))
m3p =(precision_score(y_test, y_predict, average='weighted'))
m3r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0

# PLOTTING
######

import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
    y=[m1a, m1p, m1r],
    name='max_depth=5'
)
trace2 = go.Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
   y=[m2a, m2p, m2r],
       name='max_depth=100'
)

trace3 = go.Scatter(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m3a, m3p, m3r],
       name='max_depth=5000'
)

data = [trace1, trace2,trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bar-mode')
# Out:
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/8.embed" height="525px" width="100%"></iframe>

# %%
### LOGISTIC REGRESSION

### Model 1
###########
from sklearn.linear_model import LogisticRegressionCV

lr = LogisticRegressionCV(multi_class='multinomial', tol=1e-2, solver='newton-cg', max_iter=20)
lr.fit(X_train, y_train)

from sklearn.metrics import accuracy_score

y_predict = lr.predict(X_test)

m1a = (accuracy_score(y_test, y_predict))
m1p =(precision_score(y_test, y_predict, average='weighted'))
m1r = (recall_score(y_test, y_predict, average='weighted'))


run_time = time.clock() - t0


### Model 2
###########
from sklearn.linear_model import LogisticRegressionCV

lr = LogisticRegressionCV(multi_class='ovr', tol=1e-4, solver='liblinear', max_iter=50)
lr.fit(X_train, y_train)

from sklearn.metrics import accuracy_score

y_predict = lr.predict(X_test)

m2a = (accuracy_score(y_test, y_predict))
m2p =(precision_score(y_test, y_predict, average='weighted'))
m2r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0

######################

### Model 3
###########
from sklearn.linear_model import LogisticRegressionCV

lr = LogisticRegressionCV(multi_class='multinomial', tol=1e-2, solver='lbfgs', max_iter=100)
lr.fit(X_train, y_train)

from sklearn.metrics import accuracy_score

y_predict = lr.predict(X_test)

m3a = (accuracy_score(y_test, y_predict))
m3p =(precision_score(y_test, y_predict, average='weighted'))
m3r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0



#### Model 4

#################


from sklearn.linear_model import LogisticRegressionCV

lr = LogisticRegressionCV(multi_class='ovr', tol=1e-2, solver='lbfgs', max_iter=500)
lr.fit(X_train, y_train)

y_predict = lr.predict(X_test)

m4a = (accuracy_score(y_test, y_predict))
m4p =(precision_score(y_test, y_predict, average='weighted'))
m4r = (recall_score(y_test, y_predict, average='weighted'))


run_time = time.clock() - t0



#### Model 5

######################


from sklearn.linear_model import LogisticRegressionCV

lr = LogisticRegressionCV(multi_class='multinomial', tol=1e-4, solver='saga', max_iter=2000)
lr.fit(X_train, y_train)


y_predict = lr.predict(X_test)

m5a = (accuracy_score(y_test, y_predict))
m5p =(precision_score(y_test, y_predict, average='weighted'))
m5r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0


#### PLOTTING
###############
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
    y=[m1a, m1p, m1r],
      name='multi_class=multinomial, tol=1e-2, solver=newton-cg, max_iter=20',
    
      marker=dict(
        color='rgb(255,165,165)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
    
)
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
   y=[m2a, m2p, m2r],
         name='multi_class=ovr, tol=1e-4, solver=lib-linear, max_iter=50',
    
      marker=dict(
        color='rgb(255,126,126)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
   
)

trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m3a, m3p, m3r],
        name='multi_class=multinomial, tol=1e-2, solver=lbfgs, max_iter=100',
    
      marker=dict(
        color='rgb(236,85,85)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
    
)

trace4 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m4a, m4p, m4r],
        name='multi_class=ovr, tol=1e-2, solver=lbfgs, max_iter=500',
    
      marker=dict(
        color='rgb(204,77,77)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
   
)

trace5 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m5a, m5p, m5r],
        name='multi_class=multinomial, tol=1e-4, solver=saga, max_iter=2000',
    
      marker=dict(
        color='rgb(197,53,53)',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        ),
  
)

data = [trace1, trace2,trace3,trace4,trace5]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bar-line')
# Out:
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/linear_model/sag.py:326: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/2.embed" height="525px" width="100%"></iframe>

# %%
# SVM - 1


# Model 1
#########
t0 = time.clock()

from sklearn import svm

clf = svm.SVC(gamma=2, C=0.25)
clf.fit(X, y)

from sklearn.metrics import accuracy_score

y_predict = clf.predict(X_test)

svm1 =accuracy_score(y_test, y_predict)

m1a = (accuracy_score(y_test, y_predict))
m1p =(precision_score(y_test, y_predict, average='weighted'))
m1r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0


# Model 2
#########

t0 = time.clock()

from sklearn import svm

clf = svm.SVC(gamma=2, C=0.5)
clf.fit(X, y)


y_predict = clf.predict(X_test)

m2a = (accuracy_score(y_test, y_predict))
m2p =(precision_score(y_test, y_predict, average='weighted'))
m2r = (recall_score(y_test, y_predict, average='weighted'))

run_time = time.clock() - t0

# Model 3
#########



t0 = time.clock()

from sklearn import svm


clf = svm.SVC(gamma=2, C=2)
clf.fit(X, y)


y_predict = clf.predict(X_test)


run_time = time.clock() - t0

m3a = (accuracy_score(y_test, y_predict))
m3p =(precision_score(y_test, y_predict, average='weighted'))
m3r = (recall_score(y_test, y_predict, average='weighted'))


# Plotting
#########

import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
    y=[m1a, m1p, m1r],
    name='gamma=2, C=0.25'
)
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
   y=[m2a, m2p, m2r],
       name='gamma=2, C=0.5'
)

trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall'],
     y=[m3a, m3p, m3r],
       name='gamma=2, C=2'
)

data = [trace1, trace2,trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:547: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# /Users/kimayadesai/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
##### SVM -2

import plotly.plotly as py
import plotly.graph_objs as go

# Model 1
#########
trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[61.29,37.58,61.29,30.243],
    name='kernel=linear',
    marker=dict(
        color='#1768AC',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

# Model 2
#########
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[61.31,56.20,61.31,95.029],
       name='kernel=rbf',
    marker=dict(
        color='#06BEE1',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)


data = [trace1, trace2]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
##### SVM -3 

import plotly.plotly as py
import plotly.graph_objs as go

# Model 1
#########
trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[61.30,37.58,61.30,109.733],
    name='gamma=2, C=0.25',
    marker=dict(
        color='#D7A6B3',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)
# Model 2
#########
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[61.30,37.58,61.30,133.32],
       name='gamma=2, C=0.5',
    marker=dict(
        color='#CF8BA3',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

# Model 3
#########
trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[61.33,58.70,61.33,167.029],
       name='gamma=2, C=1',
    marker=dict(
        color='#C455A8',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
##### SVM -4

import plotly.plotly as py
import plotly.graph_objs as go

# Model 1
#########
trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[61.53,67.63,61.53,320.003],
    name='C=1, gamma=10',
    marker=dict(
        color='#8DB38B',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)
# Model 2
#########
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[62.35,64.83,62.35,380.33],
       name='C=1, gamma=50',
    marker=dict(
        color='#56876D',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

# Model 3
#########
trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[63.12,65.66,63.12,409.93],
       name='C=1, gamma=100',
    marker=dict(
        color='#04724D',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)


data = [trace1, trace2, trace3]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
##### SVM - 5

import plotly.plotly as py
import plotly.graph_objs as go


# Model 1
#########
trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[67.39,70.97,67.39,361.896],
    name='C=1, gamma=1000',
    marker=dict(
        color='#fff9ae',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

# Model 2
#########
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[72.86,77.31,72.86,368.605],
    name='C=1, gamma=5000',
    marker=dict(
        color='#f8ed62',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)


# Model 3
#########
trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[75.38,79.08,75.38,323.129],
    name='C=1, gamma=10000',
    marker=dict(
        color='#e9d700',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

# Model 4
#########
trace4 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[78.65,81.44,78.65,338.190],
       name='C=1, gamma=20000',
    marker=dict(
        color='#dab600',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)
# Model 5
#########

trace5 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall', 'Runtime'],
   y=[81.69,83.77,81.69,346.780],
       name='C=1, gamma=40000',
    marker=dict(
        color='#a98600',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)



data = [trace1, trace2, trace3, trace4,trace5]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
##### SVM -6

import plotly.plotly as py
import plotly.graph_objs as go

# Model 1
#########

trace1 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[81.69,83.77,81.69,346.780],
    name='gamma=40000, C=1',
    marker=dict(
        color='#f4a8a8',
        line=dict(
            color='#EBD4CB',
            width=1.0),
        )
)

# Model 2
#########
trace2 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[86.84,87.27,86.84,468.403],
    name='gamma=40000, C=10',
    marker=dict(
        color='#df9191',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)


# Model 3
#########
trace3 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[88.04,88.30,88.04,728.391],
    name='gamma=40000, C=100',
    marker=dict(
        color='#d07c7c',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)

  
# Model 4
#########
trace4 = go.Bar(
    x=['Accuracy', 'Precision', 'Recall','Runtime'],
    y=[88.37,88.59,88.37,1819.582],
    name='gamma=40000, C=1000',
    marker=dict(
        color='#af5353',
        line=dict(
            color='rgb(8,48,107)',
            width=1.0),
        )
)


data = [trace1, trace2,trace3, trace4]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='grouped-bar')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~raghav99/0 or inside your plot.ly account where it is named 'grouped-bar'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/0.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

month = ['Random Forest', 'KNeighbors','Decision Tree', 'MLP', 'SVM', 'Logistic Regression','Bernoulli Naive Bayes','Gaussian Naive Bayes']


trace1 = go.Scatter(
    x= month,
    y= [16.417,0.812,167.029,9.928,1819.582,3.132,0.045,0.036]
    
)

data = [trace1]
layout = dict(title = 'Runtime Comparision',
              xaxis = dict(title = 'MuliClass Classification Algorithms'),
              yaxis = dict(title = 'Runtime (In Seconds)'),
              )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='styled-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/6.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

month = ['Random Forest', 'KNeighbors','Decision Tree', 'MLP', 'SVM', 'Logistic Regression','Bernoulli Naive Bayes','Gaussian Naive Bayes']

trace1 = go.Scatter(
    x= month,
    y= [61.67,61.66,61.33,61.50,88.37,61.31,61.3,21.5]
    

)

data = [trace1]
layout = dict(title = 'Accuracy Comparision',
              xaxis = dict(title = 'MuliClass Classification Algorithms'),
              yaxis = dict(title = 'Accuracy (Percentage)'),
              )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='styled-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/6.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

month = ['Random Forest', 'KNeighbors','Decision Tree', 'MLP', 'SVM', 'Logistic Regression','Bernoulli Naive Bayes','Gaussian Naive Bayes']



trace1 = go.Scatter(
    x= month,
    y= [46.84,45.59,58.70,46.00,88.59,37.58,37.5,55.6]
    

)

data = [trace1]
layout = dict(title = 'Precision Comparision',
              xaxis = dict(title = 'MuliClass Classification Algorithms'),
              yaxis = dict(title = 'Precision (Percentage)'),
              )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='styled-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/6.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

month = ['Random Forest', 'KNeighbors','Decision Tree', 'MLP', 'SVM', 'Logistic Regression','Bernoulli Naive Bayes','Gaussian Naive Bayes']


trace1 = go.Scatter(
    x= month,
    y= [61.67,61.66,61.33,61.50,88.37,61.30,61.3,21.5]
    

)

data = [trace1]
layout = dict(title = 'Recall Comparision',
              xaxis = dict(title = 'MuliClass Classification Algorithms'),
              yaxis = dict(title = 'Recall (Percentage)'),
              )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='styled-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~raghav99/6.embed" height="525px" width="100%"></iframe>
